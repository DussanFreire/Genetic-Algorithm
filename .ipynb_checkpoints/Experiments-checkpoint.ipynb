# %% [markdown]
# ## Libraries and clases used

# %%
from population import Population
from pandas import DataFrame

# %% [markdown]
# ## Auxiliar functions

# %%
def display_best_experiment(exp_reports):
    min_number_of_generation = min(list(map(lambda r: r.number_of_generations, exp_reports)))
    report_with_less_generations = list(filter(lambda r: r.number_of_generations ==min_number_of_generation,exp_reports ))
    for report in report_with_less_generations:
        report.display_results()

# %%
def display_worst_experiment(exp_reports):
    max_number_of_generation = max(list(map(lambda r: r.number_of_generations, exp_reports)))
    report_with_more_generations = list(filter(lambda r: r.number_of_generations ==max_number_of_generation,exp_reports ))
    for report in report_with_more_generations:
        report.display_results()

# %%
def display_all_experiments(exp_reports):
    for report in exp_reports:
        report.display_results()

# %%
def display_average_result(population, exp_reports):
    number_of_generations = list(map(lambda r: r.number_of_generations, exp_reports))
    max_ffs = list(map(lambda r: r.max_ffs_for_generation[-1], exp_reports))
    min_ffs = list(map(lambda r: r.min_ffs_for_generation[-1], exp_reports))
    mean_ffs = list(map(lambda r: r.mean_ffs_for_generation[-1], exp_reports))
    df_results = DataFrame({"Generations": number_of_generations, "Max Fitness functions found": max_ffs, "Min fitness function found": min_ffs, "Average fistness function":mean_ffs}, index=list(range(1, population.setting.ITERATIONS + 1)))
    average = sum(number_of_generations)/len(number_of_generations)
    print(f"The average of generations required to find the strongest FF is {average}")
    return df_results

# %% [markdown]
# # Experiments

# %% [markdown]
# ## 1 Apply the genetic algorithm to a population with the following characteristics
# * pc = 0.7
# * pm = 0.001
# * 20 genes
# * 100 chromosomes
# * 20 iterations

# %% [markdown]
# ### All experiments results

# %%
p_1 = Population()
reports_1 = p_1.run_experiment()
# display_all_experiments(reports_1)

# %% [markdown]
# ### Best experiment result

# %%
display_best_experiment(reports_1)
# Out:
# Experiment:  18
# Number of generations: 5
# Max FF: 20
# Min FF: 7
# Mean FF: 12.2

# %% [markdown]
# ### Worst experiment result

# %%
display_worst_experiment(reports_1)
# Out:
# Experiment:  10
# Number of generations: 100
# Max FF: 18
# Min FF: 17
# Mean FF: 17.92

# %% [markdown]
# ### Average Result

# %%
display_average_result(p_1, reports_1)
# Out:
# The average of generations required to find the strongest FF is 28.2
#     Generations  Max Fitness functions found  Min fitness function found  \
# 1            10                           20                           9
# 2            36                           20                          14
# 3            33                           20                          13
# 4            29                           20                          15
# 5            22                           20                          11
# 6            27                           20                          14
# 7            23                           20                          10
# 8            31                           20                          13
# 9            33                           20                          13
# 10           25                           20                          15
# 11          100                           18                          17
# 12           16                           20                          11
# 13           31                           20                          12
# 14           20                           20                          13
# 15           26                           20                          13
# 16           26                           20                          12
# 17           26                           20                          14
# 18           14                           20                           9
# 19            5                           20                           7
# 20           31                           20                          14
#
#     Average fistness function
# 1                       14.95
# 2                       17.04
# 3                       17.07
# 4                       16.88
# 5                       15.84
# 6                       16.57
# 7                       16.71
# 8                       16.18
# 9                       16.37
# 10                      16.87
# 11                      17.92
# 12                      15.24
# 13                      15.89
# 14                      16.20
# 15                      16.73
# 16                      16.14
# 17                      16.87
# 18                      13.98
# 19                      12.20
# 20                      16.90

# %% [markdown]
# ## 2. Apply the genetic algorithm to a population with the following characteristics
# * pc = 0
# * pm = 0.001
# * 20 genes
# * 100 chromosomes
# * 20 iterations
# * The max number of generations for experiments was setted as 50

# %% [markdown]
# ### All experiments results

# %%
p_2 = Population()
p_2.setting.CROSSOVER_PROB = 0
p_2.setting.MAX_GENERATIONS = 50
reports_2 = p_2.run_experiment()
# display_all_experiments(reports_2)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# In this case we would need tons of generations and luck in order to get the strongest FF.
# As we can see in the images the mean and the min FF are incrementings but the max FF stays constante, thats may be bacause of the "selection of chromosomes" based on probability weights. It seams that the crossover is crutial in order to get the strongest FF

# %% [markdown]
# ## 3. Apply the genetic algorithm to a population with the following characteristics
# * pc = 0,7
# * pm = 0
# * 20 genes
# * 100 chromosomes
# * 20 iterations
# * The max number of generations for experiments was setted as 50

# %% [markdown]
# ### All experiments results

# %%
p_3 = Population()
p_3.setting.MUTATION_PROB = 0
reports_3 = p_3.run_experiment()
# display_all_experiments(reports_3)

# %% [markdown]
# ### Best experiment result

# %%
display_best_experiment(reports_3)
# Out:
# Experiment:  12
# Number of generations: 12
# Max FF: 20
# Min FF: 8
# Mean FF: 15.25

# %% [markdown]
# ### Worst experiment result

# %%
display_worst_experiment(reports_3)
# Out:
# Experiment:  4
# Number of generations: 56
# Max FF: 20
# Min FF: 15
# Mean FF: 17.25

# %% [markdown]
# ### Average Result

# %%
display_average_result(p_3, reports_3)
# Out:
# The average of generations required to find the strongest FF is 25.9
#     Generations  Max Fitness functions found  Min fitness function found  \
# 1            34                           20                          15
# 2            26                           20                          12
# 3            27                           20                          14
# 4            37                           20                          14
# 5            56                           20                          15
# 6            18                           20                          12
# 7            20                           20                          11
# 8            20                           20                          12
# 9            16                           20                          12
# 10           25                           20                          12
# 11           17                           20                          11
# 12           18                           20                          10
# 13           12                           20                           8
# 14           32                           20                          14
# 15           28                           20                          12
# 16           22                           20                          13
# 17           20                           20                          11
# 18           25                           20                          10
# 19           28                           20                          11
# 20           37                           20                          15
#
#     Average fistness function
# 1                       17.42
# 2                       16.44
# 3                       16.92
# 4                       17.18
# 5                       17.25
# 6                       15.99
# 7                       14.98
# 8                       16.68
# 9                       16.31
# 10                      15.92
# 11                      15.39
# 12                      14.61
# 13                      15.25
# 14                      17.02
# 15                      16.17
# 16                      16.53
# 17                      15.41
# 18                      16.38
# 19                      15.99
# 20                      17.40

# %% [markdown]
# ## 4. Apply the genetic algorithm to a population with the following characteristics
# * pc = 0,9
# * pm = 0.001
# * 20 genes
# * 100 chromosomes
# * 20 iterations
# * The max number of generations for experiments was setted as 100

# %% [markdown]
# ### All experiments results

# %%
p_4 = Population()
p_4.setting.CROSSOVER_PROB = 0.9
reports_4 = p_4.run_experiment()
# display_all_experiments(reports_4)

# %% [markdown]
# ### Best experiment result

# %%
display_best_experiment(reports_4)
# Out:
# Experiment:  1
# Number of generations: 12
# Max FF: 20
# Min FF: 9
# Mean FF: 14.57

# %% [markdown]
# ### Worst experiment result

# %%
display_worst_experiment(reports_4)
# Out:
# Experiment:  15
# Number of generations: 35
# Max FF: 20
# Min FF: 12
# Mean FF: 16.49

# %% [markdown]
# ### Average Result

# %%
display_average_result(p_4, reports_4)
# Out:
# The average of generations required to find the strongest FF is 23.25
#     Generations  Max Fitness functions found  Min fitness function found  \
# 1            31                           20                          12
# 2            12                           20                           9
# 3            22                           20                          12
# 4            29                           20                          14
# 5            27                           20                          14
# 6            19                           20                          10
# 7            21                           20                          11
# 8            14                           20                          11
# 9            19                           20                          10
# 10           31                           20                          13
# 11           18                           20                          10
# 12           19                           20                          13
# 13           27                           20                          13
# 14           32                           20                          11
# 15           21                           20                          11
# 16           35                           20                          12
# 17           22                           20                          13
# 18           17                           20                          12
# 19           24                           20                          11
# 20           25                           20                          11
#
#     Average fistness function
# 1                       15.95
# 2                       14.57
# 3                       15.48
# 4                       16.76
# 5                       17.07
# 6                       16.24
# 7                       15.87
# 8                       15.39
# 9                       15.28
# 10                      16.54
# 11                      15.31
# 12                      15.97
# 13                      16.84
# 14                      15.74
# 15                      15.94
# 16                      16.49
# 17                      16.39
# 18                      15.89
# 19                      15.71
# 20                      16.38

# %% [markdown]
# ## 5. Apply the genetic algorithm to a population with the following characteristics
# * pc = 0,3
# * pm = 0.001
# * 20 genes
# * 100 chromosomes
# * 20 iterations
# * The max number of generations for experiments was setted as 100

# %% [markdown]
# ### All experiments results

# %%
p_5 = Population()
p_5.setting.CROSSOVER_PROB = 0.3
reports_5 = p_5.run_experiment()
# display_all_experiments(reports_5)

# %% [markdown]
# ### Best experiment result

# %%
display_best_experiment(reports_5)
# Out:
# Experiment:  10
# Number of generations: 14
# Max FF: 20
# Min FF: 10
# Mean FF: 15.0

# %% [markdown]
# ### Worst experiment result

# %%
display_worst_experiment(reports_5)
# Out:
# Experiment:  0
# Number of generations: 100
# Max FF: 19
# Min FF: 18
# Mean FF: 18.77
# Experiment:  1
# Number of generations: 100
# Max FF: 19
# Min FF: 17
# Mean FF: 18.18
# Experiment:  18
# Number of generations: 100
# Max FF: 19
# Min FF: 17
# Mean FF: 18.68

# %% [markdown]
# ### Average Result

# %%
display_average_result(p_5, reports_5)
# Out:
# The average of generations required to find the strongest FF is 45.25
#     Generations  Max Fitness functions found  Min fitness function found  \
# 1           100                           19                          18
# 2           100                           19                          17
# 3            56                           20                          16
# 4            27                           20                          14
# 5            46                           20                          16
# 6            35                           20                          14
# 7            55                           20                          15
# 8            19                           20                          11
# 9            45                           20                          15
# 10           35                           20                          14
# 11           14                           20                          10
# 12           28                           20                          13
# 13           28                           20                          15
# 14           66                           20                          17
# 15           46                           20                          15
# 16           29                           20                          15
# 17           22                           20                          12
# 18           31                           20                          14
# 19          100                           19                          17
# 20           23                           20                          13
#
#     Average fistness function
# 1                       18.77
# 2                       18.18
# 3                       17.50
# 4                       17.26
# 5                       17.66
# 6                       17.05
# 7                       17.54
# 8                       15.32
# 9                       17.57
# 10                      17.61
# 11                      15.00
# 12                      16.93
# 13                      16.76
# 14                      18.58
# 15                      17.81
# 16                      17.71
# 17                      15.68
# 18                      17.04
# 19                      18.68
# 20                      16.53

# %% [markdown]
# ¿Cu´al es la mejor opci´on de par´ametros seg´un los resultados obtenidos anteriormente? ¿Por qu´e?

# %% [markdown]
# ## 6. Apply the genetic algorithm to a population with the following characteristics
# * pc = 0,7
# * pm = 0.001
# * 20 genes
# * 50 chromosomes
# * 20 iterations
# * The max number of generations for experiments was setted as 100

# %% [markdown]
# ### All experiments results

# %%
p_6 = Population()
p_6.setting.CHROMOSOME_POPULATION = 50
reports_6 = p_6.run_experiment()
# display_all_experiments(reports_6)

# %% [markdown]
# ### Best experiment result

# %%
display_best_experiment(reports_6)
# Out:
# Experiment:  7
# Number of generations: 15
# Max FF: 20
# Min FF: 12
# Mean FF: 15.68

# %% [markdown]
# ### Worst experiment result

# %%
display_worst_experiment(reports_6)
# Out:
# Experiment:  2
# Number of generations: 100
# Max FF: 17
# Min FF: 16
# Mean FF: 16.5
# Experiment:  3
# Number of generations: 100
# Max FF: 18
# Min FF: 16
# Mean FF: 17.42
# Experiment:  5
# Number of generations: 100
# Max FF: 17
# Min FF: 17
# Mean FF: 17.0
# Experiment:  11
# Number of generations: 100
# Max FF: 18
# Min FF: 17
# Mean FF: 17.78
# Experiment:  12
# Number of generations: 100
# Max FF: 19
# Min FF: 18
# Mean FF: 18.54
# Experiment:  14
# Number of generations: 100
# Max FF: 17
# Min FF: 17
# Mean FF: 17.0
# Experiment:  17
# Number of generations: 100
# Max FF: 19
# Min FF: 18
# Mean FF: 18.4
# Experiment:  18
# Number of generations: 100
# Max FF: 19
# Min FF: 16
# Mean FF: 17.38

# %% [markdown]
# ### Average Result

# %%
display_average_result(p_6, reports_6)
# Out:
# The average of generations required to find the strongest FF is 60.35
#     Generations  Max Fitness functions found  Min fitness function found  \
# 1            34                           20                          14
# 2            21                           20                          14
# 3           100                           17                          16
# 4           100                           18                          16
# 5            31                           20                          15
# 6           100                           17                          17
# 7            69                           20                          17
# 8            15                           20                          12
# 9            40                           20                          15
# 10           40                           20                          14
# 11           43                           20                          14
# 12          100                           18                          17
# 13          100                           19                          18
# 14           34                           20                          13
# 15          100                           17                          17
# 16           28                           20                          13
# 17           26                           20                          11
# 18          100                           19                          18
# 19          100                           19                          16
# 20           26                           20                          14
#
#     Average fistness function
# 1                       16.18
# 2                       17.04
# 3                       16.50
# 4                       17.42
# 5                       17.44
# 6                       17.00
# 7                       17.96
# 8                       15.68
# 9                       17.12
# 10                      16.48
# 11                      16.42
# 12                      17.78
# 13                      18.54
# 14                      16.12
# 15                      17.00
# 16                      17.60
# 17                      15.06
# 18                      18.40
# 19                      17.38
# 20                      16.66

# %% [markdown]
# ## 7. Apply the genetic algorithm to a population with the following characteristics
# * pc = 0,7
# * pm = 0.001
# * 20 genes
# * 500 chromosomes
# * 20 iterations
# * The max number of generations for experiments was setted as 100

# %% [markdown]
# ### All experiments results

# %%
p_7 = Population()
p_7.setting.CHROMOSOME_POPULATION = 500
reports_7 = p_7.run_experiment()
# display_all_experiments(reports_7)

# %% [markdown]
# ### Best experiment result

# %%
display_best_experiment(reports_7)
# Out:
# Experiment:  5
# Number of generations: 11
# Max FF: 20
# Min FF: 9
# Mean FF: 13.78
# Experiment:  12
# Number of generations: 11
# Max FF: 20
# Min FF: 8
# Mean FF: 13.114
# Experiment:  16
# Number of generations: 11
# Max FF: 20
# Min FF: 8
# Mean FF: 13.812
# Experiment:  18
# Number of generations: 11
# Max FF: 20
# Min FF: 7
# Mean FF: 13.486

# %% [markdown]
# ### Worst experiment result

# %%
display_worst_experiment(reports_7)
# Out:
# Experiment:  14
# Number of generations: 22
# Max FF: 20
# Min FF: 10
# Mean FF: 15.094

# %% [markdown]
# ### Average Result

# %%
display_average_result(p_7, reports_7)
# Out:
# The average of generations required to find the strongest FF is 15.05
#     Generations  Max Fitness functions found  Min fitness function found  \
# 1            18                           20                          10
# 2            14                           20                           9
# 3            16                           20                           9
# 4            13                           20                           8
# 5            14                           20                           8
# 6            11                           20                           9
# 7            14                           20                           8
# 8            21                           20                          11
# 9            14                           20                          10
# 10           16                           20                           7
# 11           16                           20                           8
# 12           17                           20                           9
# 13           11                           20                           8
# 14           15                           20                           9
# 15           22                           20                          10
# 16           17                           20                          10
# 17           11                           20                           8
# 18           18                           20                          11
# 19           11                           20                           7
# 20           12                           20                           7
#
#     Average fistness function
# 1                      15.090
# 2                      14.720
# 3                      14.546
# 4                      14.096
# 5                      14.562
# 6                      13.780
# 7                      15.048
# 8                      15.226
# 9                      14.834
# 10                     14.696
# 11                     14.848
# 12                     15.136
# 13                     13.114
# 14                     14.598
# 15                     15.094
# 16                     14.598
# 17                     13.812
# 18                     15.514
# 19                     13.486
# 20                     13.978

# %% [markdown]
# ## 8. Apply the genetic algorithm to a population with the following characteristics
# * pc = 0,7
# * pm = 0.001
# * 20 genes
# * 1000 chromosomes
# * 20 iterations
# * The max number of generations for experiments was setted as 100

# %% [markdown]
# ### All experiments results

# %%
p_8 = Population()
p_8.setting.CHROMOSOME_POPULATION = 1000
reports_8 = p_8.run_experiment()
# display_all_experiments(reports_8)

# %% [markdown]
# ### Best experiment result

# %%
display_best_experiment(reports_8)
# Out:
# Experiment:  8
# Number of generations: 8
# Max FF: 20
# Min FF: 6
# Mean FF: 12.997

# %% [markdown]
# ### Worst experiment result

# %%
display_worst_experiment(reports_8)
# Out:
# Experiment:  7
# Number of generations: 19
# Max FF: 20
# Min FF: 9
# Mean FF: 15.361
# Experiment:  16
# Number of generations: 19
# Max FF: 20
# Min FF: 9
# Mean FF: 15.567

# %% [markdown]
# ### Average Result

# %%
display_average_result(p_8, reports_8)
# Out:
# The average of generations required to find the strongest FF is 13.1
#     Generations  Max Fitness functions found  Min fitness function found  \
# 1            11                           20                           6
# 2            15                           20                           8
# 3            11                           20                           7
# 4            13                           20                           9
# 5            18                           20                           9
# 6            13                           20                           8
# 7            14                           20                           8
# 8            19                           20                           9
# 9             8                           20                           6
# 10           14                           20                           7
# 11           11                           20                           7
# 12            9                           20                           6
# 13           15                           20                           9
# 14           17                           20                           9
# 15           10                           20                           7
# 16           13                           20                           7
# 17           19                           20                           9
# 18            9                           20                           6
# 19            9                           20                           6
# 20           14                           20                           8
#
#     Average fistness function
# 1                      13.862
# 2                      14.729
# 3                      13.962
# 4                      14.989
# 5                      15.155
# 6                      14.290
# 7                      14.517
# 8                      15.361
# 9                      12.997
# 10                     14.628
# 11                     14.057
# 12                     13.533
# 13                     15.063
# 14                     15.081
# 15                     13.661
# 16                     14.429
# 17                     15.567
# 18                     13.032
# 19                     13.073
# 20                     14.370

# %% [markdown]
# ## 9. Apply the genetic algorithm to a population with the following characteristics
# * pc = 0,7
# * pm = 0.001
# * 20 genes
# * 100 chromosomes
# * 100 iterations
# * The max number of generations for experiments was setted as 100

# %% [markdown]
# ### All experiments results

# %%
p_9 = Population()
p_9.setting.ITERATIONS = 20
reports_9 = p_9.run_experiment()
# display_all_experiments(reports_9)

# %% [markdown]
# ### Best experiment result

# %%
display_best_experiment(reports_9)
# Out:
# Experiment:  9
# Number of generations: 11
# Max FF: 20
# Min FF: 10
# Mean FF: 14.67

# %% [markdown]
# ### Worst experiment result

# %%
display_worst_experiment(reports_9)
# Out:
# Experiment:  3
# Number of generations: 78
# Max FF: 20
# Min FF: 15
# Mean FF: 17.95

# %% [markdown]
# ### Average Result

# %%
display_average_result(p_9, reports_9)
# Out:
# The average of generations required to find the strongest FF is 26.6
#     Generations  Max Fitness functions found  Min fitness function found  \
# 1            16                           20                          11
# 2            26                           20                          11
# 3            12                           20                          11
# 4            78                           20                          15
# 5            37                           20                          14
# 6            31                           20                          13
# 7            33                           20                          12
# 8            14                           20                           9
# 9            29                           20                          14
# 10           11                           20                          10
# 11           24                           20                          12
# 12           54                           20                          14
# 13           25                           20                          12
# 14           16                           20                          10
# 15           13                           20                          11
# 16           13                           20                           7
# 17           34                           20                          14
# 18           21                           20                          12
# 19           18                           20                          11
# 20           27                           20                          12
#
#     Average fistness function
# 1                       15.84
# 2                       16.27
# 3                       15.85
# 4                       17.95
# 5                       17.36
# 6                       16.45
# 7                       16.45
# 8                       14.91
# 9                       16.54
# 10                      14.67
# 11                      14.95
# 12                      17.37
# 13                      16.19
# 14                      14.58
# 15                      16.22
# 16                      14.32
# 17                      16.97
# 18                      15.70
# 19                      15.75
# 20                      16.47
